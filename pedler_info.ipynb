# %%
import pickle

# %%
import pickle

# Load the dictionary from the pickle file
with open('data/pedler_dict.pickle', 'rb') as file:
    pedler_dict = pickle.load(file)

pedler_dict
# Out:
# {'ably': ['able'],
#  'able': ['ably'],
#  'aboard': ['abroad'],
#  'abroad': ['aboard'],
#  'abut': ['about'],
#  'about': ['abut'],
#  'accept': ['except'],
#  'except': ['accept', 'excerpt'],
#  'acceptably': ['acceptable'],
#  'acceptable': ['acceptably'],
#  'accursed': ['accused'],
#  'accused': ['accursed'],
#  'ace': ['ache', 'acre', 'axe', 'age'],
#  'ache': ['ace', 'acre', 'axe'],
#  'acre': ['ace', 'ache', 'axe'],
#  'axe': ['ace', 'ache', 'acre', 'age'],
#  'aces': ['acres', 'axes', 'ages', 'axis'],
#  'acres': ['aces', 'axes'],
#  'axes': ['aces', 'acres', 'ages', 'axis'],
#  'ached': ['arched'],
#  'arched': ['ached'],
#  'aches': ['arches'],
#  'arches': ['aches'],
#  'aching': ['arching'],
#  'arching': ['aching'],
#  'action': ['auction'],
#  'auction': ['action'],
#  'actions': ['auctions'],
#  'auctions': ['actions'],
#  'ad': ['add', 'ado', 'aid'],
#  'add': ['ad', 'ado', 'aid'],
#  'ado': ['ad', 'add', 'aid'],
#  'aid': ['ad', 'add', 'ado', 'aide'],
# ...

# %%
len(pedler_dict)
# Out:
# 7164
